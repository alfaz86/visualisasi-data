# %% [markdown]
# <a href="https://colab.research.google.com/github/alfaz86/visualisasi-data/blob/main/kebutuhan_per_bulan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_kpb = pd.read_csv("/content/drive/MyDrive/dataset_visualisasidata/kebutuhan_per_bulan.csv")

# %%
df_kpb
# Out:
#            Propinsi  tahun kebutuhan
# 0              ACEH   2005    619876
# 1    SUMATERA UTARA   2005    547255
# 2    SUMATERA BARAT   2005    501315
# 3              RIAU   2005    551498
# 4             JAMBI   2005    495242
# ..              ...    ...       ...
# 369  SULAWESI BARAT   2015   1981507
# 370          MALUKU   2015   2197450
# 371    MALUKU UTARA   2015   2333166
# 372     PAPUA BARAT   2015   2255113
# 373           PAPUA   2015   2171944
#
# [374 rows x 3 columns]

# %%
x = df_kpb.Propinsi
y = df_kpb.tahun
z = df_kpb.kebutuhan

# %%
plt.figure(figsize=(18, 12))
plt.scatter(x, y, s=10);
for i in range(len(x)):
    plt.text(x[i], y[i], z[i], ha='center', va='bottom', rotation=45)
plt.title('Jumlah kebutuhan per tahun tiap provinsi')
plt.xlabel('Propinsi', fontsize=18)
plt.ylabel('Tahun', fontsize=18)
plt.xticks(rotation=90 , fontsize=6)
plt.grid()
plt.show()
