# %% [markdown]
# <a href="https://colab.research.google.com/github/alfaz86/visualisasi-data/blob/main/profile_pelanggan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_pp = pd.read_csv("/content/drive/MyDrive/dataset_visualisasidata/profile_pelanggan.csv")

# %%
df_pp
# Out:
#       jumlah     provinsi
# 0      15572  DKI Jakarta
# 1      12461   Jawa Timur
# 2      12590   Jawa Barat
# 3      16839  DKI Jakarta
# 4      13596  DKI Jakarta
# ...      ...          ...
# 2353   18261  DKI Jakarta
# 2354   18257  DKI Jakarta
# 2355   12510  Jawa Tengah
# 2356   16198  DKI Jakarta
# 2357   16235  DKI Jakarta
#
# [2358 rows x 2 columns]

# %%
x = df_pp.provinsi
y = df_pp.jumlah

# %%
plt.figure(figsize=(18, 14))
plt.scatter(x, y)
plt.title('Data profil pelanggan')
plt.xlabel('Provinsi', fontsize=18)
plt.ylabel('Jumlah', fontsize=18)
plt.xticks(rotation=90 , fontsize=6)
plt.grid()
plt.show()
