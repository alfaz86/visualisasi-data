# %% [markdown]
# <a href="https://colab.research.google.com/github/alfaz86/visualisasi-data/blob/main/produk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_p = pd.read_csv("/content/drive/MyDrive/dataset_visualisasidata/produk.csv", nrows=20)

# %%
data = df_p.produk

data = sorted(data, key=lambda x: int(x.split('|')[2]))

x = []
y = []
z = []

for i in range(len(data)):
  parts = data[i].split("|")
  x.append(parts[1])
  y.append(parts[2])
  z.append(parts[0])

data
# Out:
# ['22704|WRAP RED APPLES |8400',
#  '23006|TRAVEL CARD WALLET FLOWER MEADOW|8400',
#  '21615|4 LAVENDER BOTANICAL DINNER CANDLES|25000',
#  '22081|RIBBON REEL FLORA + FAUNA |33000',
#  '22629|SPACEBOY LUNCH BOX |33000',
#  '21932|SCANDINAVIAN PAISLEY PICNIC BAG|33000',
#  '47594B|SCOTTIES DESIGN WASHBAG|33200',
#  '20704|MR ROBOT SOFT TOY|39000',
#  '85099C|JUMBO  BAG BAROQUE BLACK WHITE|41600',
#  '84375|SET OF 20 KIDS COOKIE CUTTERS|42000',
#  '21933|PINK VINTAGE PAISLEY PICNIC BAG|49200',
#  '22966|GINGERBREAD MAN COOKIE CUTTER|49200',
#  '22989|SET 2 PANTRY DESIGN TEA TOWELS|55000',
#  '22910|PAPER CHAIN KIT VINTAGE CHRISTMAS|59000',
#  '35651|VINTAGE BEAD PINK SCARF |67200',
#  '22131|FOOD CONTAINER SET 3 LOVE HEART |82600',
#  '21426|WOODLAND STORAGE BOX SMALL|99200',
#  '22361|GLASS JAR DAISY FRESH COTTON WOOL|115800',
#  '22580|ADVENT CALENDAR GINGHAM SACK|119000',
#  '21524|DOORMAT SPOTTY HOME SWEET HOME|315800']

# %%
plt.figure(figsize=(10, 6))
plt.scatter(x, y);
plt.title('Data Produk')
plt.xlabel('Nama Produk', fontsize=12)
plt.ylabel('Harga', fontsize=12)
plt.xticks(rotation=80 , fontsize=6)
plt.grid()
plt.show()
